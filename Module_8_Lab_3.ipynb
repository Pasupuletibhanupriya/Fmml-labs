# %% [markdown]
# <a href="https://colab.research.google.com/github/Pasupuletibhanupriya/Fmml-labs/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-16 06:52:39--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  81.1MB/s    in 0.9s
#
# 2025-03-16 06:52:40 (81.1 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 32105   1303.4169v1  Since Hamming distances can be calculated by b...    cs
# 9883    1302.0723v2  A key problem of robotic environmental sensing...    cs
# 30664  1712.09792v1  In this paper, we propose a novel deep learnin...    cs
# 6866   1706.10208v1  Consider a binary decision making process wher...  stat
# 21982   1307.0323v1  The Gaussian Process Latent Variable Model (GP...  stat
# ...             ...                                                ...   ...
# 6309   1611.01971v3  Random Forests (RFs) are strong machine learni...  stat
# 22003   1310.6062v1  We introduce a computationally effective algor...  stat
# 7546   1802.03050v1  In this paper we apply active learning algorit...  stat
# 22006   1310.6778v2  We consider learning the possible causal direc...  stat
# 1051   1611.00035v1  Recurrent neural networks are powerful models ...  stat
#
#                                                    title  year  \
# 32105  Markov Chain Monte Carlo for Arrangement of Hy...  2013
# 9883   Multi-Robot Informative Path Planning for Acti...  2013
# 30664  Siamese LSTM based Fiber Structural Similarity...  2017
# 6866   On Fairness, Diversity and Randomness in Algor...  2017
# 21982  Dimensionality Detection and Integration of Mu...  2013
# ...                                                  ...   ...
# 6309     One Class Splitting Criteria for Random Forests  2016
# 22003  Combined l_1 and greedy l_0 penalized least sq...  2013
# 7546               Thompson Sampling for Dynamic Pricing  2018
# 22006  Bayesian estimation of possible causal directi...  2013
# 1051     Full-Capacity Unitary Recurrent Neural Networks  2016
#
#                                                 keywords
# 32105  [distances, calculated, computations, calculat...
# 9883   [environmental, monitoring, informative, obser...
# 30664  [architecture, combining, directional, archite...
# 6866   [classifier, multitude, questions, resulting, ...
# 21982  [probabilistic, embedding, dimensional, dimens...
# ...                                                  ...
# 6309   [classification, regression, supervised, algor...
# 22003  [introduce, computationally, effective, algori...
# 7546   [algorithms, prominent, decisions, approaches,...
# 22006  [direction, variables, confounding, variables,...
# 1051   [recurrent, processing, sequential, generally,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 32105    [distances, calculated, computations, calculat...
# 9883     [environmental, monitoring, informative, obser...
# 30664    [architecture, combining, directional, archite...
# 6866     [classifier, multitude, questions, resulting, ...
# 21982    [probabilistic, embedding, dimensional, dimens...
#                                ...
# 11432    [interactive, algorithms, interactive, algorit...
# 2475     [generation, artificial, unexpected, situation...
# 2754     [convolution, tremendous, outstanding, increas...
# 9910     [transcriptional, profiling, microarrays, expr...
# 29014    [coherence, tomography, favorable, dermatology...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8824 words.
# Out of those 4562 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="98a81d80-311e-4c34-8738-2e4ce76131db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98a81d80-311e-4c34-8738-2e4ce76131db")) {                    Plotly.newPlot(                        "98a81d80-311e-4c34-8738-2e4ce76131db",                        [{"x":["arrangements","dimensional","hyperplanes","transformation","approximate","performing","calculated","computations","computational","probability","transforms","performance","sensitive","functions","hyperplane","information","arrangement","performed","therefore","reflecting","attracting","attention","distances","supervised","similarity","practical","principled","complexity","guarantees","monitoring","approaches","theoretic","evaluation","informative","consequence","increasing","occurring","conditions","exploration","uncertainty","observation","favorable","environmental","efficient","algorithms","addressing","predicting","theoretical","efficiency","anisotropic","analytically","particular","preserving","phenomenon","empirical","phenomena","incurring","structure","important","correlation","magnitude","segmentation","thousands","capturing","relationship","structural","extensive","meaningful","invariant","difference","directional","different","architecture","combining","rotations","tractography","experimentation","importantly","multitude","resulting","distributional","algorithmic","properties","classifier","ensembles","classifiers","characterize","randomness","attractive","questions","introduce","potential","diversity","guaranteed","demonstrate","parameters","retrieval","prediction","classification","posterior","detection","embedding","appropriate","determine","representation","integrate","illustrate","synthetic","dimensionality","simultaneously","developed","hyperparameters","relevance","expansion","integration","alternative","automatic","determination","variables","variational","probabilistic","successful","estimation","hyperparameter","selection","posteriori","significant","integrated","controller","investigating","programming","satellite","autonomous","controllers","engineering","development","environment","algorithm","considered","presented","adjusting","experimental","population","significantly","triggered","generation","evolutionary","mechanism","impulsive","stabilizing","individuals","introducing","evolution","intelligently","operation","abilities","instantly","regulating","modifying","benchmark","effective","positions","differential","successfully","framework","incorporated","exploitation","determined","introduced","individual","identification","statistical","arbitrary","screening","threshold","including","improvements","throughput","estimates","applicable","experiments","accommodate","compounds","activities","candidate","providing","extension","distributions","discovery","sensitivity","implemented","specificity","essential","involving","nonparametric","identifying","description","correspond","surveillance","descriptors"],"y":[5,202,3,49,100,97,34,30,280,176,24,913,57,204,3,710,9,120,152,5,8,180,30,203,155,112,30,227,63,33,445,32,277,39,23,106,13,116,53,77,66,9,19,392,594,25,68,166,160,7,9,250,62,31,150,23,5,354,354,68,47,205,30,36,68,67,186,48,55,60,13,753,279,108,8,2,23,23,5,160,23,38,203,153,14,120,48,6,23,73,373,140,44,25,580,267,105,226,498,42,372,109,72,76,374,39,80,143,47,108,176,20,39,16,45,93,190,5,121,51,169,67,203,8,153,7,236,58,20,16,120,14,67,12,53,131,117,803,112,168,11,369,49,244,7,161,67,109,2,2,40,57,57,5,34,9,3,1,8,211,251,20,20,89,557,31,15,37,125,113,98,183,74,10,37,230,99,9,83,65,559,12,2,48,50,101,67,120,46,33,106,7,61,52,14,81,72,24,31,44],"type":"bar"},{"x":["arrangements","dimensional","hyperplanes","transformation","approximate","performing ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4562,), (4562, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.81

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fisher</span> <span style=''>Motion</span> <span style='background-color:rgba(0, 255, 0, 0.7333333333333334);'>Descriptor</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Multiview</span> <span style=''>Gait</span> <span style='background-color:rgba(0, 255, 0, 0.6659619450317126);'>Recognition</span> <br/><br/><span style=''>The</span> <span style=''>goal</span> <span style=''>of</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>to</span> <span style=''>identify</span> <span style='background-color:rgba(0, 255, 0, 0.3114754098360655);'>individuals</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analyzing</span> <span style=''>their</span> <span style=''>gait</span> <span style=''>Instead</span> <span style=''>of</span> <span style=''>using</span> <span style=''>binary</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>silhouettes</span> <span style=''>as</span> <span style=''>input</span> <span style=''>data</span> <span style=''>(as</span> <span style=''>done</span> <span style=''>in</span> <span style=''>many</span> <span style=''>previous</span> <span style=''>works)</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>and</span> <span style=''>evaluate</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>motion</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>descriptors</span> <span style=''>based</span> <span style=''>on</span> <span style=''>densely</span> <span style=''>sampled</span> <span style=''>short</span> <span style=''>term</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>trajectories</span> <span style=''>We</span> <span style=''>take</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>people</span> <span style='background-color:rgba(0, 255, 0, 0.7948717948717949);'>detectors</span> <span style=''>to</span> <span style=''>define</span> <span style=''>custom</span> <span style=''>spatial</span> <span style='background-color:rgba(0, 255, 0, 0.3529411764705883);'>configurations</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>descriptors</span> <span style=''>around</span> <span style=''>the</span> <span style=''>target</span> <span style=''>person</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>obtaining</span> <span style=''>a</span> <span style=''>rich</span> <span style='background-color:rgba(0, 255, 0, 0.3877551020408163);'>representation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>gait</span> <span style=''>motion</span> <span style=''>The</span> <span style=''>local</span> <span style=''>motion</span> <span style=''>features</span> <span style=''>(described</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>Divergence</span> <span style=''>Curl</span> <span style=''>Shear</span> <span style=''>descriptor)</span> <span style='background-color:rgba(0, 255, 0, 0.6888888888888889);'>extracted</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3280423280423281);'>different</span> <span style=''>spatial</span> <span style=''>areas</span> <span style=''>of</span> <span style=''>the</span> <span style=''>person</span> <span style=''>are</span> <span style=''>combined</span> <span style=''>into</span> <span style=''>a</span> <span style=''>single</span> <span style=''>high</span> <span style=''>level</span> <span style=''>gait</span> <span style='background-color:rgba(0, 255, 0, 0.7333333333333334);'>descriptor</span> <span style=''>by</span> <span style=''>using</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>of</span> <span style=''>Low</span> <span style=''>Rank</span> <span style=''>Density</span> <span style=''>Matrices</span> <br/><br/><span style=''>The</span> <span style=''>density</span> <span style=''>matrices</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>positively</span> <span style=''>semi</span> <span style=''>definite</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hermitian</span> <span style=''>matrices</span> <span style=''>of</span> <span style=''>unit</span> <span style=''>trace</span> <span style=''>that</span> <span style=''>describe</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>a</span> <span style=''>quantum</span> <span style=''>system</span> <span style=''>The</span> <span style=''>goal</span> <span style=''>of</span> <span style=''>the</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>minimax</span> <span style=''>lower</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>error</span> <span style=''>rates</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>density</span> <span style=''>matrices</span> <span style=''>in</span> <span style=''>trace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>models</span> <span style=''>used</span> <span style=''>in</span> <span style=''>quantum</span> <span style=''>state</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tomography</span> <span style=''>(in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>in</span> <span style=''>the</span> <span style=''>case</span> <span style=''>of</span> <span style=''>Pauli</span> <span style=''>measurements)</span> <span style=''>with</span> <span style=''>explicit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependence</span> <span style=''>of</span> <span style=''>the</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style=''>rank</span> <span style=''>and</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>Such</span> <span style=''>bounds</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>established</span> <span style=''>for</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistically</span> <span style=''>relevant</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>quantum</span> <span style=''>versions</span> <span style=''>of</span> <span style=''>Kullback</span> <span style=''>Leibler</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>divergence</span> <span style=''>(relative</span> <span style=''>entropy</span> <span style=''>distance)</span> <span style=''>and</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Hellinger</span> <span style=''>distance</span> <span style=''>(so</span> <span style=''>called</span> <span style=''>Bures</span> <span style=''>distance)</span> <span style=''>and</span> <span style=''>Schatten</span> <span style=''>p</span> <span style=''>norm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>Sharp</span> <span style=''>upper</span> <span style=''>bounds</span> <span style=''>and</span> <span style=''>oracle</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inequa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3833333333333333);'>factorization</span> <span style='background-color:rgba(255, 0, 0, 0.3739130434782609);'>criterion</span> <span style=''>for</span> <span style=''>acyclic</span> <span style=''>directed</span> <span style=''>mixed</span> <span style=''>graphs</span> <br/><br/><span style=''>Acyclic</span> <span style=''>directed</span> <span style=''>mixed</span> <span style=''>graphs</span> <span style=''>also</span> <span style=''>known</span> <span style=''>as</span> <span style=''>semi</span> <span style=''>Markov</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.33980582524271846);'>represent</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(255, 0, 0, 0.3095238095238094);'>independence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>induced</span> <span style=''>on</span> <span style=''>an</span> <span style=''>observed</span> <span style=''>margin</span> <span style=''>by</span> <span style=''>a</span> <span style=''>DAG</span> <span style=''>model</span> <span style=''>with</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.40686274509803916);'>variables</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3833333333333333);'>factorization</span> <span style='background-color:rgba(255, 0, 0, 0.3739130434782609);'>criterion</span> <span style=''>for</span> <span style=''>these</span> <span style=''>models</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style=''>the</span> <span style=''>global</span> <span style=''>Markov</span> <span style=''>property</span> <span style=''>given</span> <span style=''>by</span> <span style=''>(the</span> <span style=''>natural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style=''>of)</span> <span style=''>d</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separation</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Taming</span> <span style=''>Wild</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensional</span> <span style=''>Text</span> <span style=''>Data</span> <span style=''>with</span> <span style=''>a</span> <span style=''>Fuzzy</span> <span style=''>Lash</span> <br/><br/><span style=''>The</span> <span style=''>bag</span> <span style=''>of</span> <span style=''>words</span> <span style=''>(BOW)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represents</span> <span style=''>a</span> <span style=''>corpus</span> <span style=''>in</span> <span style=''>a</span> <span style=''>matrix</span> <span style=''>whose</span> <span style=''>elements</span> <span style=''>are</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frequency</span> <span style=''>of</span> <span style=''>words</span> <span style=''>However</span> <span style=''>each</span> <span style=''>row</span> <span style=''>in</span> <span style=''>the</span> <span style=''>matrix</span> <span style=''>is</span> <span style=''>a</span> <span style=''>very</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>sparse</span> <span style=''>vector</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimension</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>(DR)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>popular</span> <span style=''>method</span> <span style=''>to</span> <span style=''>address</span> <span style=''>sparsity</span> <span style=''>and</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style=''>issues</span> <span style=''>Among</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>DR</span> <span style=''>method</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Unsupervised</span> <span style=''>Feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Transformation</span> <span style=''>(UFT)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>popular</span> <span style=''>strategy</span> <span style=''>to</span> <span style=''>map</span> <span style=''>all</span> <span style=''>words</span> <span style=''>on</span> <span style=''>a</span> <span style=''>new</span> <span style=''>basis</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style=''>BOW</span> <span style=''>The</span> <span style=''>recent</span> <span style=''>increase</span> <span style=''>of</span> <span style=''>text</span> <span style=''>data</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenges</span> <span style=''>imply</span> <span style=''>that</span> <span style=''>DR</span> <span style=''>area</span> <span style=''>still</span> <span style=''>needs</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perspectives</span> <span style=''>Although</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>range</span> <span style=''>of</span> <span style=''>methods</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>UFT</span> <span style=''>strategy</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>the</span> <span style=''>fuzzy</span> <span style=''>approach</span> <span style=''>has</span> <span style=''>not</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>for</span> <span style=''>DR</span> <span sty ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.13328581610833928)
# 	experimental (0.13150392017106202)
# 	segmentation (0.07305773342836779)
# 	information (0.25302922309337134)
# 	knowledge (0.13114754098360656)
# 	architecture (0.09942979330007128)
# 	different (0.2683535281539558)
# 	detection (0.13257305773342837)
# 	recognition (0.14041339985744833)
# 	convolutional (0.1421952957947256)
#
# Some Statistics words are:
# 	theoretical (0.1469408224674022)
# 	stochastic (0.1374122367101304)
# 	estimation (0.16599799398194584)
# 	algorithm (0.3811434302908726)
# 	statistical (0.16449348044132397)
# 	variables (0.14393179538615847)
# 	distribution (0.17953861584754263)
# 	dimensional (0.18455366098294884)
# 	inference (0.20110330992978936)
# 	regression (0.17753259779338015)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b5fc0d55-24dc-4bb1-a726-1ee19882ad0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5fc0d55-24dc-4bb1-a726-1ee19882ad0f")) {                    Plotly.newPlot(                        "b5fc0d55-24dc-4bb1-a726-1ee19882ad0f",                        [{"x":["arrangements","dimensional","hyperplanes","transformation","approximate","performing","calculated","computations","computational","probability","transforms","performance","sensitive","functions","hyperplane","information","arrangement","performed","therefore","reflecting","attracting","attention","distances","supervised","similarity","practical","principled","complexity","guarantees","monitoring","approaches","theoretic","evaluation","informative","consequence","increasing","occurring","conditions","exploration","uncertainty","observation","favorable","environmental","efficient","algorithms","addressing","predicting","theoretical","efficiency","anisotropic","analytically","particular","preserving","phenomenon","empirical","phenomena","incurring","structure","important","correlation","magnitude","segmentation","thousands","capturing","relationship","structural","extensive","meaningful","invariant","difference","directional","different","architecture","combining","rotations","tractography","experimentation","importantly","multitude","resulting","distributional","algorithmic","properties","classifier","ensembles","classifiers","characterize","randomness","attractive","questions","introduce","potential","diversity","guaranteed","demonstrate","parameters","retrieval","prediction","classification","posterior","detection","embedding","appropriate","determine","representation","integrate","illustrate","synthetic","dimensionality","simultaneously","developed","hyperparameters","relevance","expansion","integration","alternative","automatic","determination","variables","variational","probabilistic","successful","estimation","hyperparameter","selection","posteriori","significant","integrated","controller","investigating","programming","satellite","autonomous","controllers","engineering","development","environment","algorithm","considered","presented","adjusting","experimental","population","significantly","triggered","generation","evolutionary","mechanism","impulsive","stabilizing","individuals","introducing","evolution","intelligently","operation","abilities","instantly","regulating","modifying","benchmark","effective","positions","differential","successfully","framework","incorporated","exploitation","determined","introduced","individual","identification","statistical","arbitrary","screening","threshold","including","improvements","throughput","estimates","applicable","experiments","accommodate","compounds","activities","candidate","providing","extension","distributions","discovery","sensitivity","implemented","specificity","essential","involving","nonparametric","identifying","description","correspond","surveillance","descriptors","reasoning","geometrical","application","recognition","describing","reference","coefficients","relationships","structured","nonlinear","transformations","preliminary","considering","comprehensively","utterance","previously","incremental","typically","optimization","stochastic","approximations","assignments","constrained","posteriors","integrates","acceptable","respectively","difficulty","especially","outstanding","consumption","solutions","traveling","migration","predetermined","parallelism","traditional","subpopulation","instances","distributed","mentioned","according","situation","intervals","nevertheless","combinations","advantage","selecting","divergence","literature","generalization","exponential","divergences","architectures","densities","addi ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	chemoinformatics
# 	nonstationary
# 	tibshirani
# 	retention
# 	nonstationarity
# 	covariates
# 	concordance
# 	disclosed
# 	prognostic
# 	equitability
# 	bernstein
# 	factorisation
# 	disentanglement
# 	factorial
# 	particulars
# 	candecompparafac
# 	chemometrics
# 	lindenstrauss
# 	permitting
# 	quadrature
# Some words which never appear in Statistics papers:
# 	incurring
# 	triggered
# 	traveling
# 	subpopulation
# 	volumetric
# 	categorizes
# 	attractiveness
# 	actuators
# 	concurrent
# 	argumentation
# 	nonmonotonic
# 	discontinuities
# 	transmitted
# 	psychology
# 	developmental
# 	declarative
# 	superpixel
# 	disparity
# 	illumination
# 	programmers

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.065415976948072e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.775
